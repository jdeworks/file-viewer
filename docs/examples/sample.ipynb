# %% [markdown]
# # Notebook demo
#
# This `.ipynb` renders **markdown cells**, code cells, and their saved outputs — all in the secure sandboxed preview. The notebook's code is *never executed*.

# %%
msg = "Hello from a saved notebook output!"
print(msg)
# Out:
# Hello from a saved notebook output!

# %%
import pandas as pd
pd.DataFrame({'n': [1, 2, 3], 'n squared': [1, 4, 9]})
# Out:
#    n  n squared
# 0  1          1
# 1  2          4
# 2  3          9

# %%
1 / 0
# Out:
# ZeroDivisionError: division by zero
